# %% [markdown]
# # Training a model

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="YOUR_API_KEY")
project = rf.workspace("fishbehaviour").project("dataset_video1") 
version = project.version(1)
dataset = version.download("yolov9")
# !pip install ultralytics

# %% [markdown]
# * Video 2
# project = rf.workspace("fishbehaviour").project("prova01_train_videodos")
#
# * Video 3
# project = rf.workspace("fishbehaviour").project("dataset_video3")
#
# * Video 4
# project = rf.workspace("fishbehaviour").project("dataset_video4-laude")

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov9c.pt")  # load a pretrained model (recommended for training)

# %%
results = model.train(data="/content/prova01_train_videoUno-1/data.yaml", epochs=20, imgsz=640, batch=8)

# %%
results = model.train(data="dataset_video1-1/data.yaml", epochs=20, imgsz=640, batch=8)

# %%
resultsVal = model.val(
    data = "",
    conf = 0.5,
    save = T,
    plots = T
)
