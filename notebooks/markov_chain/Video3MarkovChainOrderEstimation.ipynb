# %%
import numpy as np
from scipy.stats import chi2
import pandas as pd

# %%
projectPath = "./data/"
file_path = projectPath + "timeVideo3.csv"
df = pd.read_csv(file_path)
df
# Out:
#          TIME behaviour
# 0    00:00:00    NIP_IN
# 1    00:00:15    NIP_IN
# 2    00:00:30    NIP_IN
# 3    00:00:45    NIP_IN
# 4    00:01:00    NIP_IN
# ..        ...       ...
# 799  03:19:45   NIP_OUT
# 800  03:20:00        AM
# 801  03:20:15        AM
# 802  03:20:30        AM
# 803  03:20:45        AM
#
# [804 rows x 2 columns]

# %%
df.describe()
# Out:
#             TIME behaviour
# count        804       577
# unique       804        19
# top     00:00:00       MAN
# freq           1       113

# %% [markdown]
# **Removing consecutive behaviours' sequences**

# %%
df['behaviour_next'] = df['behaviour'].shift(-1)
df = df[df['behaviour'] != df['behaviour_next']]
df = df.drop('behaviour_next', axis=1)

# %%
df
# Out:
#          TIME behaviour
# 6    00:01:30    NIP_IN
# 7    00:01:45       NaN
# 8    00:02:00       NaN
# 9    00:02:15       NaN
# 10   00:02:30       NaN
# ..        ...       ...
# 790  03:17:30       FAN
# 791  03:17:45       NaN
# 796  03:19:00       MAN
# 799  03:19:45   NIP_OUT
# 803  03:20:45        AM
#
# [318 rows x 2 columns]

# %%
#remove NaN
dfNoNan = df[df['behaviour'].notna()]

# %%
dfNoNan
# Out:
#          TIME behaviour
# 6    00:01:30    NIP_IN
# 41   00:10:15       MAN
# 43   00:10:45      SPIT
# 71   00:17:45   NIP_OUT
# 86   00:21:30        AM
# ..        ...       ...
# 768  03:12:00      ROLL
# 790  03:17:30       FAN
# 796  03:19:00       MAN
# 799  03:19:45   NIP_OUT
# 803  03:20:45        AM
#
# [91 rows x 2 columns]

# %%
Courtship_all = ['BEND', 'DAN_CIRC', 'ROLL', 'GB', 'LF', 'BK_SW', 'BEND_OPP', 'H_DOWN', 'H_UP', 'MAF', 'UP', 'INSF', 'SPA']
Nest_mantainance = ['SA', 'NIP_OUT', 'NIP_IN', 'BN', 'AM', 'LAND', 'MAN', 'NIP_CORE' ]
Egg_care = ['FAN', 'NIP_CORE', 'INSF']
Agonism = ['CHA/flee', 'MAF']

# %%
Courtship_df = df[df["behaviour"].isin(Courtship_all)]
Courtship_df
# Out:
#          TIME behaviour
# 234  00:58:30      ROLL
# 239  00:59:45        LF
# 245  01:01:15     BK_SW
# 252  01:03:00        LF
# 272  01:08:00      BEND
# 277  01:09:15      ROLL
# 284  01:11:00        LF
# 286  01:11:30      BEND
# 290  01:12:30  DAN_CIRC
# 294  01:13:30      BEND
# 295  01:13:45        GB
# 298  01:14:30       SPA
# 304  01:16:00      BEND
# 308  01:17:00       SPA
# 313  01:18:15      BEND
# 325  01:21:15  DAN_CIRC
# 337  01:24:15      BEND
# 340  01:25:00        LF
# 359  01:29:45      ROLL
# 362  01:30:30      BEND
# 372  01:33:00  DAN_CIRC
# 374  01:33:30      BEND
# 386  01:36:30        LF
# 401  01:40:15      BEND
# 404  01:41:00        GB
# 414  01:43:30  DAN_CIRC
# 416  01:44:00      BEND
# 417  01:44:15        GB
# 478  01:59:30  BEND_OPP
# 489  02:02:15  BEND_OPP
# 495  02:03:45      ROLL
# 496  02:04:00  BEND_OPP
# 501  02:05:15      ROLL
# 506  02:06:30  BEND_OPP
# 508  02:07:00      BEND
# 510  02:07:30  DAN_CIRC
# 512  02:08:00      BEND
# 517  02:09:15        GB
# 520  02:10:00       SPA
# 556  02:19:00      INSF
# 605  02:31:15      INSF
# 615  02:33:45      INSF
# 632  02:38:00      BEND
# 637  02:39:15  DAN_CIRC
# 641  02:40:15      BEND
# 644  02:41:00       SPA
# 652  02:43:00       SPA
# 692  02:53:00      INSF
# 696  02:54:00      INSF
# 705  02:56:15      BEND
# 718  02:59:30  DAN_CIRC
# 721  03:00:15      BEND
# 722  03:00:30        GB
# 725  03:01:15       SPA
# 738  03:04:30       SPA
# 749  03:07:15        GB
# 760  03:10:00        LF
# 768  03:12:00      ROLL

# %%
Nest_mantainance_df = df[df["behaviour"].isin(Nest_mantainance)]
Nest_mantainance_df
# Out:
#          TIME behaviour
# 6    00:01:30    NIP_IN
# 41   00:10:15       MAN
# 71   00:17:45   NIP_OUT
# 86   00:21:30        AM
# 90   00:22:30    NIP_IN
# 113  00:28:15       MAN
# 118  00:29:30  NIP_CORE
# 121  00:30:15       MAN
# 131  00:32:45  NIP_CORE
# 161  00:40:15       MAN
# 167  00:41:45    NIP_IN
# 173  00:43:15       MAN
# 210  00:52:30       MAN
# 213  00:53:15  NIP_CORE
# 466  01:56:30        BN
# 471  01:57:45  NIP_CORE
# 572  02:23:00  NIP_CORE
# 611  02:32:45  NIP_CORE
# 695  02:53:45  NIP_CORE
# 796  03:19:00       MAN
# 799  03:19:45   NIP_OUT
# 803  03:20:45        AM

# %%
Egg_care_df = df[df["behaviour"].isin(Egg_care)]
Egg_care_df
# Out:
#          TIME behaviour
# 118  00:29:30  NIP_CORE
# 131  00:32:45  NIP_CORE
# 213  00:53:15  NIP_CORE
# 471  01:57:45  NIP_CORE
# 545  02:16:15       FAN
# 556  02:19:00      INSF
# 565  02:21:15       FAN
# 572  02:23:00  NIP_CORE
# 601  02:30:15       FAN
# 605  02:31:15      INSF
# 611  02:32:45  NIP_CORE
# 615  02:33:45      INSF
# 631  02:37:45       FAN
# 690  02:52:30       FAN
# 692  02:53:00      INSF
# 695  02:53:45  NIP_CORE
# 696  02:54:00      INSF
# 704  02:56:00       FAN
# 790  03:17:30       FAN

# %%
Agonism_df = df[df["behaviour"].isin(Agonism)]
Agonism_df
# Out:
# Empty DataFrame
# Columns: [TIME, behaviour]
# Index: []

# %%
sequence = df["behaviour"].replace(np.nan, "notKnown").tolist()  # Replace "NaN" with nan and generate list
sequence = [seq for i, seq in enumerate(sequence) if i == 0 or seq != sequence[i - 1]]
sequence
# Out:
# ['NIP_IN',
#  'notKnown',
#  'MAN',
#  'SPIT',
#  'notKnown',
#  'NIP_OUT',
#  'notKnown',
#  'AM',
#  'NIP_IN',
#  'MAN',
#  'NIP_CORE',
#  'MAN',
#  'NIP_CORE',
#  'MAN',
#  'NIP_IN',
#  'MAN',
#  'FS',
#  'MAN',
#  'NIP_CORE',
#  'notKnown',
#  'ROLL',
#  'notKnown',
#  'LF',
#  'BK_SW',
#  'LF',
#  'notKnown',
#  'BEND',
#  'notKnown',
#  'ROLL',
#  'LF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'BEND',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'notKnown',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'notKnown',
#  'LF',
#  'notKnown',
#  'BEND',
#  'notKnown',
#  'GB',
#  'notKnown',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'notKnown',
#  'CHASE_FLEE',
#  'notKnown',
#  'CHASE_FLEE',
#  'notKnown',
#  'BN',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'BEND_OPP',
#  'notKnown',
#  'BEND_OPP',
#  'notKnown',
#  'ROLL',
#  'BEND_OPP',
#  'notKnown',
#  'ROLL',
#  'BEND_OPP',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'notKnown',
#  'GB',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'FAN',
#  'notKnown',
#  'INSF',
#  'notKnown',
#  'FAN',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'FAN',
#  'notKnown',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'notKnown',
#  'FAN',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'FAN',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'notKnown',
#  'FAN',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'GB',
#  'notKnown',
#  'LF',
#  'notKnown',
#  'ROLL',
#  'notKnown',
#  'FAN',
#  'notKnown',
#  'MAN',
#  'NIP_OUT',
#  'AM']

# %%
states = list(set(sequence))  # Unique states
states
# Out:
# ['LF',
#  'MAN',
#  'FS',
#  'BEND',
#  'NIP_CORE',
#  'INSF',
#  'DAN_CIRC',
#  'FAN',
#  'notKnown',
#  'BK_SW',
#  'GB',
#  'NIP_OUT',
#  'BEND_OPP',
#  'ROLL',
#  'NIP_IN',
#  'SPIT',
#  'BN',
#  'SPA',
#  'AM',
#  'CHASE_FLEE']

# %%
def get_transition_counts(seq, order):
    counts = {}
    for i in range(len(seq) - order):
        state = tuple(seq[i:i+order])
        next_state = seq[i+order]
        if state not in counts:
            counts[state] = {s: 0 for s in states}
        counts[state][next_state] += 1
    return counts

# %%
# Metrics calculation
def calculate_metrics(seq, order):
    counts = get_transition_counts(seq, order)
    chi_square = 0
    df = 0
    for state, next_states in counts.items():
        total = sum(next_states.values())
        expected = total / len(states)
        for next_state, observed in next_states.items():
            chi_square += (observed - expected) ** 2 / expected
        df += len(states) - 1
    p_value = 1 - chi2.cdf(chi_square, df)
    log_likelihood = 0
    for state, next_states in counts.items():
        total = sum(next_states.values())
        for next_state, count in next_states.items():
            if count > 0:
                log_likelihood += count * np.log(count / total)
    k = len(states)**(order + 1)
    aic = 2*k - 2*log_likelihood
    bic = np.log(len(seq))*k - 2*log_likelihood
    return chi_square, df, p_value, aic, bic

# %%
# Test per ordini 0, 1, 2, e 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 261.06
#  Degrees of freedom: 19
#  p-value: 0.0000
#  AIC: 702.11
#  BIC: 760.36
#
# Order 1:
#  Chi-square statistic: 1021.21
#  Degrees of freedom: 380
#  p-value: 0.0000
#  AIC: 1151.43
#  BIC: 2316.49
#
# Order 2:
#  Chi-square statistic: 1622.76
#  Degrees of freedom: 988
#  p-value: 0.0000
#  AIC: 16152.96
#  BIC: 39454.20
#
# Order 3:
#  Chi-square statistic: 1907.48
#  Degrees of freedom: 1577
#  p-value: 0.0000
#  AIC: 320097.29
#  BIC: 786122.07

# %% [markdown]
# **Calculate metrics without NAN**

# %%
sequence = dfNoNan["behaviour"].tolist()  # genera lista
sequence
# Out:
# ['NIP_IN',
#  'MAN',
#  'SPIT',
#  'NIP_OUT',
#  'AM',
#  'NIP_IN',
#  'MAN',
#  'NIP_CORE',
#  'MAN',
#  'NIP_CORE',
#  'MAN',
#  'NIP_IN',
#  'MAN',
#  'FS',
#  'MAN',
#  'NIP_CORE',
#  'ROLL',
#  'LF',
#  'BK_SW',
#  'LF',
#  'BEND',
#  'ROLL',
#  'LF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'BEND',
#  'SPA',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'BEND',
#  'GB',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'CHASE_FLEE',
#  'CHASE_FLEE',
#  'BN',
#  'NIP_CORE',
#  'BEND_OPP',
#  'BEND_OPP',
#  'ROLL',
#  'BEND_OPP',
#  'ROLL',
#  'BEND_OPP',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'FAN',
#  'INSF',
#  'FAN',
#  'NIP_CORE',
#  'FAN',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'SPA',
#  'SPA',
#  'FAN',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'SPA',
#  'GB',
#  'LF',
#  'ROLL',
#  'FAN',
#  'MAN',
#  'NIP_OUT',
#  'AM']

# %%
states = list(set(sequence))  # Stati unici, escludendo None
states
# Out:
# ['LF',
#  'MAN',
#  'FS',
#  'BEND',
#  'NIP_CORE',
#  'INSF',
#  'DAN_CIRC',
#  'FAN',
#  'BK_SW',
#  'GB',
#  'NIP_OUT',
#  'BEND_OPP',
#  'ROLL',
#  'NIP_IN',
#  'SPIT',
#  'BN',
#  'SPA',
#  'AM',
#  'CHASE_FLEE']

# %%
def get_transition_counts(seq, order):
    counts = {}
    for i in range(len(seq) - order):
        state = tuple(seq[i:i+order])
        next_state = seq[i+order]
        if state not in counts:
            counts[state] = {s: 0 for s in states}
        counts[state][next_state] += 1
    return counts

# %%
# Funzione per calcolare le metriche
def calculate_metrics(seq, order):
    counts = get_transition_counts(seq, order)
    chi_square = 0
    df = 0
    for state, next_states in counts.items():
        total = sum(next_states.values())
        expected = total / len(states)
        for next_state, observed in next_states.items():
            chi_square += (observed - expected) ** 2 / expected
        df += len(states) - 1
    p_value = 1 - chi2.cdf(chi_square, df)
    log_likelihood = 0
    for state, next_states in counts.items():
        total = sum(next_states.values())
        for next_state, count in next_states.items():
            if count > 0:
                log_likelihood += count * np.log(count / total)
    k = len(states)**(order + 1)
    aic = 2*k - 2*log_likelihood
    bic = np.log(len(seq))*k - 2*log_likelihood
    return chi_square, df, p_value, aic, bic

# %%
# Test per ordini 0, 1, 2, e 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 49.93
#  Degrees of freedom: 18
#  p-value: 0.0001
#  AIC: 527.44
#  BIC: 575.15
#
# Order 1:
#  Chi-square statistic: 668.17
#  Degrees of freedom: 342
#  p-value: 0.0000
#  AIC: 907.56
#  BIC: 1813.98
#
# Order 2:
#  Chi-square statistic: 1130.80
#  Degrees of freedom: 882
#  p-value: 0.0000
#  AIC: 13794.30
#  BIC: 31016.28
#
# Order 3:
#  Chi-square statistic: 1371.83
#  Degrees of freedom: 1242
#  p-value: 0.0057
#  AIC: 260676.32
#  BIC: 587894.04

# %% [markdown]
# **CALCULATE METRICS PER BEHAVIOUR GROUPS**

# %% [markdown]
# **COURTSHIP**

# %%
sequence = Courtship_df["behaviour"].tolist()
sequence
# Out:
# ['ROLL',
#  'LF',
#  'BK_SW',
#  'LF',
#  'BEND',
#  'ROLL',
#  'LF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'BEND',
#  'SPA',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'BEND',
#  'GB',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'BEND_OPP',
#  'BEND_OPP',
#  'ROLL',
#  'BEND_OPP',
#  'ROLL',
#  'BEND_OPP',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'INSF',
#  'INSF',
#  'INSF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'SPA',
#  'SPA',
#  'INSF',
#  'INSF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'SPA',
#  'GB',
#  'LF',
#  'ROLL']

# %%
states = list(set(sequence))  # Stati unici
states
# Out:
# ['LF', 'INSF', 'DAN_CIRC', 'BEND_OPP', 'ROLL', 'BEND', 'BK_SW', 'GB', 'SPA']

# %%
# Test per orders 0, 1, 2, and 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 20.21
#  Degrees of freedom: 8
#  p-value: 0.0096
#  AIC: 254.11
#  BIC: 272.66
#
# Order 1:
#  Chi-square statistic: 163.19
#  Degrees of freedom: 72
#  p-value: 0.0000
#  AIC: 279.15
#  BIC: 446.05
#
# Order 2:
#  Chi-square statistic: 284.80
#  Degrees of freedom: 208
#  p-value: 0.0003
#  AIC: 1514.52
#  BIC: 3016.58
#
# Order 3:
#  Chi-square statistic: 348.50
#  Degrees of freedom: 320
#  p-value: 0.1312
#  AIC: 13153.54
#  BIC: 26672.11

# %% [markdown]
# **Nest Mantainance**

# %%
sequence = Nest_mantainance_df["behaviour"].tolist()
sequence
# Out:
# ['NIP_IN',
#  'MAN',
#  'NIP_OUT',
#  'AM',
#  'NIP_IN',
#  'MAN',
#  'NIP_CORE',
#  'MAN',
#  'NIP_CORE',
#  'MAN',
#  'NIP_IN',
#  'MAN',
#  'MAN',
#  'NIP_CORE',
#  'BN',
#  'NIP_CORE',
#  'NIP_CORE',
#  'NIP_CORE',
#  'NIP_CORE',
#  'MAN',
#  'NIP_OUT',
#  'AM']

# %%
states = list(set(sequence))
states
# Out:
# ['NIP_CORE', 'AM', 'MAN', 'NIP_IN', 'BN', 'NIP_OUT']

# %%
# Test per orders 0, 1, 2, and 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 9.64
#  Degrees of freedom: 5
#  p-value: 0.0862
#  AIC: 81.38
#  BIC: 87.93
#
# Order 1:
#  Chi-square statistic: 50.14
#  Degrees of freedom: 30
#  p-value: 0.0120
#  AIC: 103.94
#  BIC: 143.22
#
# Order 2:
#  Chi-square statistic: 60.00
#  Degrees of freedom: 55
#  p-value: 0.2994
#  AIC: 452.82
#  BIC: 688.49
#
# Order 3:
#  Chi-square statistic: 83.00
#  Degrees of freedom: 85
#  p-value: 0.5412
#  AIC: 2597.55
#  BIC: 4011.54

# %% [markdown]
# **EGG CARE**

# %%
sequence = Egg_care_df["behaviour"].tolist()  # Sostituisci "NaN" con nan e genera lista
sequence
# Out:
# ['NIP_CORE',
#  'NIP_CORE',
#  'NIP_CORE',
#  'NIP_CORE',
#  'FAN',
#  'INSF',
#  'FAN',
#  'NIP_CORE',
#  'FAN',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'FAN',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'FAN']

# %%
states = list(set(sequence))
states
# Out:
# ['NIP_CORE', 'FAN', 'INSF']

# %%
# Test per orders 0, 1, 2, and 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 0.42
#  Degrees of freedom: 2
#  p-value: 0.8102
#  AIC: 47.31
#  BIC: 50.14
#
# Order 1:
#  Chi-square statistic: 4.09
#  Degrees of freedom: 6
#  p-value: 0.6651
#  AIC: 51.97
#  BIC: 60.47
#
# Order 2:
#  Chi-square statistic: 22.00
#  Degrees of freedom: 16
#  p-value: 0.1432
#  AIC: 65.46
#  BIC: 90.96
#
# Order 3:
#  Chi-square statistic: 26.00
#  Degrees of freedom: 22
#  p-value: 0.2517
#  AIC: 167.55
#  BIC: 244.04

# %% [markdown]
# **Agonistic**

# %%
sequence = Agonism_df["behaviour"].tolist()
sequence
# Out:
# []

# %%
states = list(set(sequence))
states
# Out:
# ['CHA/flee', 'MAF']

# %%
# Test per orders 0, 1, 2, and 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 0.33
#  Degrees of freedom: 1
#  p-value: 0.5637
#  AIC: 7.82
#  BIC: 6.02
#
# Order 1:
#  Chi-square statistic: 2.00
#  Degrees of freedom: 2
#  p-value: 0.3679
#  AIC: 8.00
#  BIC: 4.39
#
# Order 2:
#  Chi-square statistic: 1.00
#  Degrees of freedom: 1
#  p-value: 0.3173
#  AIC: 16.00
#  BIC: 8.79
#
# Order 3:
#  Chi-square statistic: 0.00
#  Degrees of freedom: 0
#  p-value: nan
#  AIC: 32.00
#  BIC: 17.58
