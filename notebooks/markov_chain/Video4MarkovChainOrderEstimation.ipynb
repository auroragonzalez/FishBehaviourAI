# %%
import numpy as np
from scipy.stats import chi2
import pandas as pd

# %%
projectPath = "./data/"
file_path = projectPath + "timeVideo4.csv"
df = pd.read_csv(file_path)
df
# Out:
#           TIME behaviour
# 0     00:00:00       NaN
# 1     00:00:15       NaN
# 2     00:00:30       NaN
# 3     00:00:45       NaN
# 4     00:01:00       NaN
# ...        ...       ...
# 1323  05:30:45        LF
# 1324  05:31:00        LF
# 1325  05:31:15        LF
# 1326  05:31:30        LF
# 1327  05:31:45       MAF
#
# [1328 rows x 2 columns]

# %%
df.describe()
# Out:
#             TIME behaviour Unnamed: 2 Unnamed: 3
# count       1328       961          2         11
# unique      1328        17          1          2
# top     00:00:00       FAN      tolti         BN
# freq           1       194          2          7

# %% [markdown]
# **Removing consecutive behaviours' sequences**

# %%
df['behaviour_next'] = df['behaviour'].shift(-1)
df = df[df['behaviour'] != df['behaviour_next']]
df = df.drop('behaviour_next', axis=1)
df
# Out:
#           TIME behaviour
# 0     00:00:00       NaN
# 1     00:00:15       NaN
# 2     00:00:30       NaN
# 3     00:00:45       NaN
# 4     00:01:00       NaN
# ...        ...       ...
# 1303  05:25:45  NIP_CORE
# 1312  05:28:00      INSF
# 1321  05:30:15       FAN
# 1326  05:31:30        LF
# 1327  05:31:45       MAF
#
# [492 rows x 2 columns]

# %%
#Remove NaN
dfNoNan = df[df['behaviour'].notna()]
dfNoNan
# Out:
#           TIME behaviour
# 13    00:03:15       FAN
# 23    00:05:45        LF
# 34    00:08:30       FAN
# 38    00:09:30        LF
# 50    00:12:30      BEND
# ...        ...       ...
# 1303  05:25:45  NIP_CORE
# 1312  05:28:00      INSF
# 1321  05:30:15       FAN
# 1326  05:31:30        LF
# 1327  05:31:45       MAF
#
# [125 rows x 2 columns]

# %%
Courtship_all = ['BEND', 'DAN_CIRC', 'ROLL', 'GB', 'LF', 'BK_SW', 'BEND_OPP', 'H_DOWN', 'H_UP', 'MAF', 'UP', 'INSF', 'SPA']
Nest_mantainance = ['SA', 'NIP_OUT', 'NIP_IN', 'BN', 'AM', 'LAND', 'MAN', 'NIP_CORE' ]
Egg_care = ['FAN', 'NIP_CORE', 'INSF']
Agonism = ['CHA/flee', 'MAF']

# %%
Courtship_df = df[df["behaviour"].isin(Courtship_all)]
Courtship_df
# Out:
#           TIME behaviour
# 23    00:05:45        LF
# 38    00:09:30        LF
# 50    00:12:30      BEND
# 55    00:13:45  DAN_CIRC
# 61    00:15:15      BEND
# ...        ...       ...
# 1273  05:18:15      ROLL
# 1288  05:22:00      ROLL
# 1312  05:28:00      INSF
# 1326  05:31:30        LF
# 1327  05:31:45       MAF
#
# [81 rows x 2 columns]

# %%
Nest_mantainance_df = df[df["behaviour"].isin(Nest_mantainance)]
Nest_mantainance_df
# Out:
#           TIME behaviour
# 134   00:33:30        BN
# 178   00:44:30  NIP_CORE
# 240   01:00:00    NIP_IN
# 296   01:14:00  NIP_CORE
# 319   01:19:45  NIP_CORE
# 458   01:54:30  NIP_CORE
# 467   01:56:45       MAN
# 478   01:59:30    NIP_IN
# 497   02:04:15    NIP_IN
# 507   02:06:45  NIP_CORE
# 599   02:29:45       MAN
# 612   02:33:00    NIP_IN
# 677   02:49:15    NIP_IN
# 692   02:53:00  NIP_CORE
# 711   02:57:45        BN
# 843   03:30:45        BN
# 872   03:38:00  NIP_CORE
# 1008  04:12:00    NIP_IN
# 1013  04:13:15       MAN
# 1049  04:22:15  NIP_CORE
# 1071  04:27:45    NIP_IN
# 1220  05:05:00  NIP_CORE
# 1230  05:07:30        AM
# 1232  05:08:00    NIP_IN
# 1254  05:13:30  NIP_CORE
# 1297  05:24:15    NIP_IN
# 1303  05:25:45  NIP_CORE

# %%
Egg_care_df = df[df["behaviour"].isin(Egg_care)]
Egg_care_df
# Out:
#           TIME behaviour
# 13    00:03:15       FAN
# 34    00:08:30       FAN
# 169   00:42:15       FAN
# 178   00:44:30  NIP_CORE
# 208   00:52:00      INSF
# 216   00:54:00       FAN
# 296   01:14:00  NIP_CORE
# 313   01:18:15      INSF
# 319   01:19:45  NIP_CORE
# 337   01:24:15      INSF
# 420   01:45:00       FAN
# 458   01:54:30  NIP_CORE
# 507   02:06:45  NIP_CORE
# 563   02:20:45       FAN
# 590   02:27:30       FAN
# 602   02:30:30       FAN
# 692   02:53:00  NIP_CORE
# 721   03:00:15       FAN
# 747   03:06:45       FAN
# 763   03:10:45       FAN
# 802   03:20:30       FAN
# 847   03:31:45       FAN
# 872   03:38:00  NIP_CORE
# 1049  04:22:15  NIP_CORE
# 1220  05:05:00  NIP_CORE
# 1254  05:13:30  NIP_CORE
# 1269  05:17:15       FAN
# 1303  05:25:45  NIP_CORE
# 1312  05:28:00      INSF
# 1321  05:30:15       FAN

# %%
Agonism_df = df[df["behaviour"].isin(Agonism)]
Agonism_df
# Out:
#           TIME behaviour
# 660   02:45:00       MAF
# 699   02:54:45       MAF
# 1083  04:30:45       MAF
# 1109  04:37:15       MAF
# 1327  05:31:45       MAF

# %%
sequence = df["behaviour"].replace(np.nan, "notKnown").tolist()  # Replace "NaN" with nan and generate list
sequence = [seq for i, seq in enumerate(sequence) if i == 0 or seq != sequence[i - 1]]
sequence
# Out:
# ['notKnown',
#  'FAN',
#  'LF',
#  'notKnown',
#  'FAN',
#  'LF',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'notKnown',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'CHASE_FLEE',
#  'notKnown',
#  'BN',
#  'notKnown',
#  'INS',
#  'notKnown',
#  'FAN',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'LF',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BK_SW',
#  'notKnown',
#  'BEND',
#  'notKnown',
#  'INSF',
#  'FAN',
#  'notKnown',
#  'NIP_IN',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'INSF',
#  'NIP_CORE',
#  'notKnown',
#  'INSF',
#  'notKnown',
#  'ROLL',
#  'BK_SW',
#  'notKnown',
#  'ROLL',
#  'notKnown',
#  'FAN',
#  'LF',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'MAN',
#  'notKnown',
#  'NIP_IN',
#  'notKnown',
#  'NIP_IN',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'BK_SW',
#  'ROLL',
#  'notKnown',
#  'ROLL',
#  'notKnown',
#  'FAN',
#  'ROLL',
#  'FAN',
#  'MAN',
#  'FAN',
#  'notKnown',
#  'NIP_IN',
#  'notKnown',
#  'ROLL',
#  'notKnown',
#  'LF',
#  'MAF',
#  'notKnown',
#  'NIP_IN',
#  'notKnown',
#  'NIP_CORE',
#  'LF',
#  'MAF',
#  'BN',
#  'FAN',
#  'LF',
#  'notKnown',
#  'FAN',
#  'LF',
#  'FAN',
#  'LF',
#  'FAN',
#  'LF',
#  'BK_SW',
#  'BEND',
#  'BK_SW',
#  'notKnown',
#  'BN',
#  'FAN',
#  'NIP_CORE',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'ROLL',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'GB',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'NIP_IN',
#  'MAN',
#  'NIP_CORE',
#  'notKnown',
#  'ROLL',
#  'notKnown',
#  'NIP_IN',
#  'ROLL',
#  'MAF',
#  'ROLL',
#  'notKnown',
#  'BEND',
#  'ROLL',
#  'MAF',
#  'BEND',
#  'DAN_CIRC',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'notKnown',
#  'GB',
#  'notKnown',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'notKnown',
#  'SPA',
#  'notKnown',
#  'GB',
#  'notKnown',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'AM',
#  'NIP_IN',
#  'notKnown',
#  'NIP_CORE',
#  'notKnown',
#  'FAN',
#  'ROLL',
#  'notKnown',
#  'ROLL',
#  'notKnown',
#  'NIP_IN',
#  'notKnown',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'LF',
#  'MAF']

# %%
states = list(set(sequence))  # Unique states
states
# Out:
# ['DAN_CIRC',
#  'MAF',
#  'GB',
#  'notKnown',
#  'SPA',
#  'FAN',
#  'MAN',
#  'BN',
#  'ROLL',
#  'INS',
#  'NIP_CORE',
#  'AM',
#  'CHASE_FLEE',
#  'LF',
#  'BK_SW',
#  'INSF',
#  'BEND',
#  'NIP_IN']

# %%
def get_transition_counts(seq, order):
    counts = {}
    for i in range(len(seq) - order):
        state = tuple(seq[i:i+order])
        next_state = seq[i+order]
        if state not in counts:
            counts[state] = {s: 0 for s in states}
        counts[state][next_state] += 1
    return counts

# %%
# Metrics calculation
def calculate_metrics(seq, order):
    counts = get_transition_counts(seq, order)
    chi_square = 0
    df = 0
    for state, next_states in counts.items():
        total = sum(next_states.values())
        expected = total / len(states)
        for next_state, observed in next_states.items():
            chi_square += (observed - expected) ** 2 / expected
        df += len(states) - 1
    p_value = 1 - chi2.cdf(chi_square, df)
    log_likelihood = 0
    for state, next_states in counts.items():
        total = sum(next_states.values())
        for next_state, count in next_states.items():
            if count > 0:
                log_likelihood += count * np.log(count / total)
    k = len(states)**(order + 1)
    aic = 2*k - 2*log_likelihood
    bic = np.log(len(seq))*k - 2*log_likelihood
    return chi_square, df, p_value, aic, bic

# %%
# Test per ordini 0, 1, 2, e 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 271.78
#  Degrees of freedom: 17
#  p-value: 0.0000
#  AIC: 898.12
#  BIC: 955.69
#
# Order 1:
#  Chi-square statistic: 990.56
#  Degrees of freedom: 306
#  p-value: 0.0000
#  AIC: 1173.23
#  BIC: 2209.54
#
# Order 2:
#  Chi-square statistic: 1739.00
#  Degrees of freedom: 1139
#  p-value: 0.0000
#  AIC: 11923.00
#  BIC: 30576.63
#
# Order 3:
#  Chi-square statistic: 2339.00
#  Degrees of freedom: 1972
#  p-value: 0.0000
#  AIC: 210078.01
#  BIC: 545843.43

# %% [markdown]
# **Metrics calculation without NAN**

# %%
sequence = dfNoNan["behaviour"].tolist()
sequence
# Out:
# ['FAN',
#  'LF',
#  'FAN',
#  'LF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'CHASE_FLEE',
#  'BN',
#  'INS',
#  'FAN',
#  'NIP_CORE',
#  'LF',
#  'BEND',
#  'DAN_CIRC',
#  'BK_SW',
#  'BEND',
#  'INSF',
#  'FAN',
#  'NIP_IN',
#  'NIP_CORE',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'ROLL',
#  'BK_SW',
#  'ROLL',
#  'FAN',
#  'LF',
#  'NIP_CORE',
#  'MAN',
#  'NIP_IN',
#  'NIP_IN',
#  'NIP_CORE',
#  'BK_SW',
#  'ROLL',
#  'ROLL',
#  'FAN',
#  'ROLL',
#  'FAN',
#  'MAN',
#  'FAN',
#  'NIP_IN',
#  'ROLL',
#  'LF',
#  'MAF',
#  'NIP_IN',
#  'NIP_CORE',
#  'LF',
#  'MAF',
#  'BN',
#  'FAN',
#  'LF',
#  'FAN',
#  'LF',
#  'FAN',
#  'LF',
#  'FAN',
#  'LF',
#  'BK_SW',
#  'BEND',
#  'BK_SW',
#  'BN',
#  'FAN',
#  'NIP_CORE',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'GB',
#  'SPA',
#  'NIP_IN',
#  'MAN',
#  'NIP_CORE',
#  'ROLL',
#  'NIP_IN',
#  'ROLL',
#  'MAF',
#  'ROLL',
#  'BEND',
#  'ROLL',
#  'MAF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'GB',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'NIP_CORE',
#  'AM',
#  'NIP_IN',
#  'NIP_CORE',
#  'FAN',
#  'ROLL',
#  'ROLL',
#  'NIP_IN',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'LF',
#  'MAF']

# %%
states = list(set(sequence))  # Unique states
states
# Out:
# ['DAN_CIRC',
#  'MAF',
#  'GB',
#  'SPA',
#  'FAN',
#  'MAN',
#  'BN',
#  'ROLL',
#  'INS',
#  'NIP_CORE',
#  'AM',
#  'CHASE_FLEE',
#  'LF',
#  'BK_SW',
#  'INSF',
#  'BEND',
#  'NIP_IN']

# %%
# Test per ordini 0, 1, 2, e 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 67.71
#  Degrees of freedom: 16
#  p-value: 0.0000
#  AIC: 672.18
#  BIC: 720.26
#
# Order 1:
#  Chi-square statistic: 607.08
#  Degrees of freedom: 272
#  p-value: 0.0000
#  AIC: 902.42
#  BIC: 1719.81
#
# Order 2:
#  Chi-square statistic: 1215.28
#  Degrees of freedom: 1008
#  p-value: 0.0000
#  AIC: 9972.91
#  BIC: 23868.41
#
# Order 3:
#  Chi-square statistic: 1699.35
#  Degrees of freedom: 1568
#  p-value: 0.0109
#  AIC: 167088.11
#  BIC: 403311.70

# %% [markdown]
# **CALCULATING METRICS PER BEHAVIOUR GROUP**

# %% [markdown]
# **COURTSHIP**

# %%
sequence = Courtship_df["behaviour"].tolist()
sequence
# Out:
# ['LF',
#  'LF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'DAN_CIRC',
#  'BEND',
#  'LF',
#  'LF',
#  'BEND',
#  'DAN_CIRC',
#  'BK_SW',
#  'BEND',
#  'INSF',
#  'INSF',
#  'INSF',
#  'ROLL',
#  'BK_SW',
#  'ROLL',
#  'LF',
#  'BK_SW',
#  'ROLL',
#  'ROLL',
#  'ROLL',
#  'ROLL',
#  'LF',
#  'MAF',
#  'LF',
#  'MAF',
#  'LF',
#  'LF',
#  'LF',
#  'LF',
#  'BK_SW',
#  'BEND',
#  'BK_SW',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'ROLL',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'GB',
#  'SPA',
#  'ROLL',
#  'ROLL',
#  'MAF',
#  'ROLL',
#  'BEND',
#  'ROLL',
#  'MAF',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'SPA',
#  'GB',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'DAN_CIRC',
#  'BEND',
#  'GB',
#  'ROLL',
#  'ROLL',
#  'INSF',
#  'LF',
#  'MAF']

# %%
states = list(set(sequence))
states
# Out:
# ['DAN_CIRC', 'MAF', 'GB', 'SPA', 'ROLL', 'LF', 'BK_SW', 'INSF', 'BEND']

# %%
# Test per orders 0, 1, 2, and 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 26.67
#  Degrees of freedom: 8
#  p-value: 0.0008
#  AIC: 347.73
#  BIC: 369.28
#
# Order 1:
#  Chi-square statistic: 188.58
#  Degrees of freedom: 72
#  p-value: 0.0000
#  AIC: 353.96
#  BIC: 547.91
#
# Order 2:
#  Chi-square statistic: 344.20
#  Degrees of freedom: 272
#  p-value: 0.0020
#  AIC: 1564.50
#  BIC: 3310.06
#
# Order 3:
#  Chi-square statistic: 494.74
#  Degrees of freedom: 456
#  p-value: 0.1020
#  AIC: 13165.34
#  BIC: 28875.32

# %% [markdown]
# **Nest Mantainance**

# %%
sequence = Nest_mantainance_df["behaviour"].tolist()  # Sostituisci "NaN" con nan e genera lista
sequence
# Out:
# ['BN',
#  'NIP_CORE',
#  'NIP_IN',
#  'NIP_CORE',
#  'NIP_CORE',
#  'NIP_CORE',
#  'MAN',
#  'NIP_IN',
#  'NIP_IN',
#  'NIP_CORE',
#  'MAN',
#  'NIP_IN',
#  'NIP_IN',
#  'NIP_CORE',
#  'BN',
#  'BN',
#  'NIP_CORE',
#  'NIP_IN',
#  'MAN',
#  'NIP_CORE',
#  'NIP_IN',
#  'NIP_CORE',
#  'AM',
#  'NIP_IN',
#  'NIP_CORE',
#  'NIP_IN',
#  'NIP_CORE']

# %%
states = list(set(sequence))
states
# Out:
# ['MAN', 'BN', 'NIP_CORE', 'NIP_IN', 'AM']

# %%
# Test per orders 0, 1, 2, and 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 13.93
#  Degrees of freedom: 4
#  p-value: 0.0075
#  AIC: 82.49
#  BIC: 88.97
#
# Order 1:
#  Chi-square statistic: 31.44
#  Degrees of freedom: 20
#  p-value: 0.0496
#  AIC: 102.33
#  BIC: 134.73
#
# Order 2:
#  Chi-square statistic: 67.50
#  Degrees of freedom: 52
#  p-value: 0.0729
#  AIC: 273.37
#  BIC: 435.35
#
# Order 3:
#  Chi-square statistic: 81.00
#  Degrees of freedom: 76
#  p-value: 0.3261
#  AIC: 1258.32
#  BIC: 2068.22

# %% [markdown]
# **EGG CARE**

# %%
sequence = Egg_care_df["behaviour"].tolist()  # Sostituisci "NaN" con nan e genera lista
sequence
# Out:
# ['FAN',
#  'FAN',
#  'FAN',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'NIP_CORE',
#  'INSF',
#  'NIP_CORE',
#  'INSF',
#  'FAN',
#  'NIP_CORE',
#  'NIP_CORE',
#  'FAN',
#  'FAN',
#  'FAN',
#  'NIP_CORE',
#  'FAN',
#  'FAN',
#  'FAN',
#  'FAN',
#  'FAN',
#  'NIP_CORE',
#  'NIP_CORE',
#  'NIP_CORE',
#  'NIP_CORE',
#  'FAN',
#  'NIP_CORE',
#  'INSF',
#  'FAN']

# %%
states = list(set(sequence))
states
# Out:
# ['NIP_CORE', 'INSF', 'FAN']

# %%
# Test per ordini 0, 1, 2, e 3
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 6.20
#  Degrees of freedom: 2
#  p-value: 0.0450
#  AIC: 64.99
#  BIC: 69.19
#
# Order 1:
#  Chi-square statistic: 11.11
#  Degrees of freedom: 6
#  p-value: 0.0850
#  AIC: 65.60
#  BIC: 78.21
#
# Order 2:
#  Chi-square statistic: 19.25
#  Degrees of freedom: 14
#  p-value: 0.1556
#  AIC: 90.58
#  BIC: 128.42
#
# Order 3:
#  Chi-square statistic: 24.80
#  Degrees of freedom: 26
#  p-value: 0.5303
#  AIC: 190.23
#  BIC: 303.73

# %% [markdown]
# **Agonistic**

# %%
sequence = Agonism_df["behaviour"].tolist()
sequence
# Out:
# ['MAF', 'MAF', 'MAF', 'MAF', 'MAF']

# %%
states = list(set(sequence))
states
# Out:
# ['MAF']

# %%
for order in range(4):
    chi_square, df, p_value, aic, bic = calculate_metrics(sequence, order)
    print(f"Order {order}:")
    print(f" Chi-square statistic: {chi_square:.2f}")
    print(f" Degrees of freedom: {df}")
    print(f" p-value: {p_value:.4f}")
    print(f" AIC: {aic:.2f}")
    print(f" BIC: {bic:.2f}")
    print()
# Out:
# Order 0:
#  Chi-square statistic: 0.00
#  Degrees of freedom: 0
#  p-value: nan
#  AIC: 2.00
#  BIC: 1.61
#
# Order 1:
#  Chi-square statistic: 0.00
#  Degrees of freedom: 0
#  p-value: nan
#  AIC: 2.00
#  BIC: 1.61
#
# Order 2:
#  Chi-square statistic: 0.00
#  Degrees of freedom: 0
#  p-value: nan
#  AIC: 2.00
#  BIC: 1.61
#
# Order 3:
#  Chi-square statistic: 0.00
#  Degrees of freedom: 0
#  p-value: nan
#  AIC: 2.00
#  BIC: 1.61
